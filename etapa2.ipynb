# %%
import time
import os
from grafos import carregar_instancia
from etapa2 import path_scanning, salvar_resultado_arquivo, GrafoCARPAdaptado 


# --- Execução do Algoritmo Path-Scanning para todos os arquivos ---

pasta_instancias = "instancias" 
pasta_saida = "solucoes"
os.makedirs(pasta_saida, exist_ok=True)  

# Lista todos os arquivos .dat na pasta de instâncias
arquivos_instancias = [f for f in os.listdir(pasta_instancias) if f.endswith('.dat')]
arquivos_instancias.sort() 

print(f"Processando {len(arquivos_instancias)} arquivos na pasta '{pasta_instancias}'...")

for i, nome_arquivo_dat in enumerate(arquivos_instancias):
    caminho_arquivo = os.path.join(pasta_instancias, nome_arquivo_dat)
    
    print(f"\n--- [{i+1}/{len(arquivos_instancias)}] Processando: {nome_arquivo_dat} ---")

    try:
        grafo_data, num_vertices = carregar_instancia(caminho_arquivo)
    except FileNotFoundError:
        print(f"Erro: O arquivo '{caminho_arquivo}' não foi encontrado. Pulando para o próximo.")
        continue 
    except Exception as e:
        print(f"Erro ao carregar o arquivo '{caminho_arquivo}': {e}. Pulando para o próximo.")
        continue

    # Cria uma instância da classe adaptadora para o Path-Scanning
    grafo_adaptado = GrafoCARPAdaptado(grafo_data, num_vertices)

    inicio_total = time.monotonic_ns()
    inicio_solucao = time.monotonic_ns()

    # Executa o algoritmo Path-Scanning
    try:
        resultado = path_scanning(grafo_adaptado)
    except Exception as e:
        print(f"Erro ao executar Path-Scanning para '{nome_arquivo_dat}': {e}. Pulando para o próximo.")
        continue

    fim_solucao = time.monotonic_ns()
    fim_total = time.monotonic_ns()

    tempo_geral = fim_total - inicio_total
    tempo_algoritmo = fim_solucao - inicio_solucao
    
    # Obtém o nome base do arquivo para usar no nome da saída
    nome_base_arquivo = nome_arquivo_dat.replace('.dat','')
    nome_saida = f"sol-{nome_base_arquivo}.dat"
    caminho_saida = os.path.join(pasta_saida, nome_saida)

    # Salva o resultado no arquivo
    try:
        salvar_resultado_arquivo(resultado, tempo_geral, tempo_algoritmo, caminho_saida)
        print(f"✅ Resultado salvo em {caminho_saida}")
    except Exception as e:
        print(f"Erro ao salvar o resultado para '{nome_arquivo_dat}': {e}")
# Out:
# Processando 378 arquivos na pasta 'instancias'...
#
# --- [1/378] Processando: BHW1.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW1.dat
#
# --- [2/378] Processando: BHW10.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW10.dat
#
# --- [3/378] Processando: BHW11.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW11.dat
#
# --- [4/378] Processando: BHW14.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW14.dat
#
# --- [5/378] Processando: BHW15.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW15.dat
#
# --- [6/378] Processando: BHW18.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW18.dat
#
# --- [7/378] Processando: BHW19.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW19.dat
#
# --- [8/378] Processando: BHW2.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW2.dat
#
# --- [9/378] Processando: BHW3.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW3.dat
#
# --- [10/378] Processando: BHW4.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW4.dat
#
# --- [11/378] Processando: BHW5.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW5.dat
#
# --- [12/378] Processando: BHW6.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW6.dat
#
# --- [13/378] Processando: BHW7.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW7.dat
#
# --- [14/378] Processando: BHW8.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW8.dat
#
# --- [15/378] Processando: BHW9.dat ---
# ✅ Resultado salvo em solucoes\sol-BHW9.dat
#
# --- [16/378] Processando: CBMix1.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix1.dat
#
# --- [17/378] Processando: CBMix10.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix10.dat
#
# --- [18/378] Processando: CBMix11.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix11.dat
#
# --- [19/378] Processando: CBMix12.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix12.dat
#
# --- [20/378] Processando: CBMix14.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix14.dat
#
# --- [21/378] Processando: CBMix15.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix15.dat
#
# --- [22/378] Processando: CBMix16.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix16.dat
#
# --- [23/378] Processando: CBMix17.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix17.dat
#
# --- [24/378] Processando: CBMix18.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix18.dat
#
# --- [25/378] Processando: CBMix2.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix2.dat
#
# --- [26/378] Processando: CBMix20.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix20.dat
#
# --- [27/378] Processando: CBMix21.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix21.dat
#
# --- [28/378] Processando: CBMix22.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix22.dat
#
# --- [29/378] Processando: CBMix23.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix23.dat
#
# --- [30/378] Processando: CBMix3.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix3.dat
#
# --- [31/378] Processando: CBMix4.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix4.dat
#
# --- [32/378] Processando: CBMix5.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix5.dat
#
# --- [33/378] Processando: CBMix6.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix6.dat
#
# --- [34/378] Processando: CBMix7.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix7.dat
#
# --- [35/378] Processando: CBMix8.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix8.dat
#
# --- [36/378] Processando: CBMix9.dat ---
# ✅ Resultado salvo em solucoes\sol-CBMix9.dat
#
# --- [37/378] Processando: mggdb_0.25_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_1.dat
#
# --- [38/378] Processando: mggdb_0.25_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_10.dat
#
# --- [39/378] Processando: mggdb_0.25_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_11.dat
#
# --- [40/378] Processando: mggdb_0.25_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_12.dat
#
# --- [41/378] Processando: mggdb_0.25_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_13.dat
#
# --- [42/378] Processando: mggdb_0.25_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_14.dat
#
# --- [43/378] Processando: mggdb_0.25_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_15.dat
#
# --- [44/378] Processando: mggdb_0.25_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_16.dat
#
# --- [45/378] Processando: mggdb_0.25_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_17.dat
#
# --- [46/378] Processando: mggdb_0.25_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_18.dat
#
# --- [47/378] Processando: mggdb_0.25_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_19.dat
#
# --- [48/378] Processando: mggdb_0.25_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_2.dat
#
# --- [49/378] Processando: mggdb_0.25_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_20.dat
#
# --- [50/378] Processando: mggdb_0.25_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_21.dat
#
# --- [51/378] Processando: mggdb_0.25_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_22.dat
#
# --- [52/378] Processando: mggdb_0.25_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_23.dat
#
# --- [53/378] Processando: mggdb_0.25_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_3.dat
#
# --- [54/378] Processando: mggdb_0.25_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_4.dat
#
# --- [55/378] Processando: mggdb_0.25_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_5.dat
#
# --- [56/378] Processando: mggdb_0.25_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_6.dat
#
# --- [57/378] Processando: mggdb_0.25_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_7.dat
#
# --- [58/378] Processando: mggdb_0.25_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_8.dat
#
# --- [59/378] Processando: mggdb_0.25_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.25_9.dat
#
# --- [60/378] Processando: mggdb_0.30_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_1.dat
#
# --- [61/378] Processando: mggdb_0.30_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_10.dat
#
# --- [62/378] Processando: mggdb_0.30_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_11.dat
#
# --- [63/378] Processando: mggdb_0.30_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_12.dat
#
# --- [64/378] Processando: mggdb_0.30_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_13.dat
#
# --- [65/378] Processando: mggdb_0.30_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_14.dat
#
# --- [66/378] Processando: mggdb_0.30_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_15.dat
#
# --- [67/378] Processando: mggdb_0.30_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_16.dat
#
# --- [68/378] Processando: mggdb_0.30_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_17.dat
#
# --- [69/378] Processando: mggdb_0.30_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_18.dat
#
# --- [70/378] Processando: mggdb_0.30_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_19.dat
#
# --- [71/378] Processando: mggdb_0.30_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_2.dat
#
# --- [72/378] Processando: mggdb_0.30_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_20.dat
#
# --- [73/378] Processando: mggdb_0.30_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_21.dat
#
# --- [74/378] Processando: mggdb_0.30_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_22.dat
#
# --- [75/378] Processando: mggdb_0.30_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_23.dat
#
# --- [76/378] Processando: mggdb_0.30_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_3.dat
#
# --- [77/378] Processando: mggdb_0.30_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_4.dat
#
# --- [78/378] Processando: mggdb_0.30_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_5.dat
#
# --- [79/378] Processando: mggdb_0.30_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_6.dat
#
# --- [80/378] Processando: mggdb_0.30_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_7.dat
#
# --- [81/378] Processando: mggdb_0.30_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_8.dat
#
# --- [82/378] Processando: mggdb_0.30_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.30_9.dat
#
# --- [83/378] Processando: mggdb_0.35_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_1.dat
#
# --- [84/378] Processando: mggdb_0.35_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_10.dat
#
# --- [85/378] Processando: mggdb_0.35_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_11.dat
#
# --- [86/378] Processando: mggdb_0.35_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_12.dat
#
# --- [87/378] Processando: mggdb_0.35_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_13.dat
#
# --- [88/378] Processando: mggdb_0.35_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_14.dat
#
# --- [89/378] Processando: mggdb_0.35_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_15.dat
#
# --- [90/378] Processando: mggdb_0.35_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_16.dat
#
# --- [91/378] Processando: mggdb_0.35_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_17.dat
#
# --- [92/378] Processando: mggdb_0.35_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_18.dat
#
# --- [93/378] Processando: mggdb_0.35_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_19.dat
#
# --- [94/378] Processando: mggdb_0.35_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_2.dat
#
# --- [95/378] Processando: mggdb_0.35_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_20.dat
#
# --- [96/378] Processando: mggdb_0.35_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_21.dat
#
# --- [97/378] Processando: mggdb_0.35_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_22.dat
#
# --- [98/378] Processando: mggdb_0.35_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_23.dat
#
# --- [99/378] Processando: mggdb_0.35_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_3.dat
#
# --- [100/378] Processando: mggdb_0.35_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_4.dat
#
# --- [101/378] Processando: mggdb_0.35_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_5.dat
#
# --- [102/378] Processando: mggdb_0.35_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_6.dat
#
# --- [103/378] Processando: mggdb_0.35_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_7.dat
#
# --- [104/378] Processando: mggdb_0.35_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_8.dat
#
# --- [105/378] Processando: mggdb_0.35_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.35_9.dat
#
# --- [106/378] Processando: mggdb_0.40_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_1.dat
#
# --- [107/378] Processando: mggdb_0.40_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_10.dat
#
# --- [108/378] Processando: mggdb_0.40_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_11.dat
#
# --- [109/378] Processando: mggdb_0.40_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_12.dat
#
# --- [110/378] Processando: mggdb_0.40_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_13.dat
#
# --- [111/378] Processando: mggdb_0.40_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_14.dat
#
# --- [112/378] Processando: mggdb_0.40_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_15.dat
#
# --- [113/378] Processando: mggdb_0.40_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_16.dat
#
# --- [114/378] Processando: mggdb_0.40_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_17.dat
#
# --- [115/378] Processando: mggdb_0.40_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_18.dat
#
# --- [116/378] Processando: mggdb_0.40_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_19.dat
#
# --- [117/378] Processando: mggdb_0.40_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_2.dat
#
# --- [118/378] Processando: mggdb_0.40_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_20.dat
#
# --- [119/378] Processando: mggdb_0.40_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_21.dat
#
# --- [120/378] Processando: mggdb_0.40_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_22.dat
#
# --- [121/378] Processando: mggdb_0.40_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_23.dat
#
# --- [122/378] Processando: mggdb_0.40_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_3.dat
#
# --- [123/378] Processando: mggdb_0.40_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_4.dat
#
# --- [124/378] Processando: mggdb_0.40_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_5.dat
#
# --- [125/378] Processando: mggdb_0.40_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_6.dat
#
# --- [126/378] Processando: mggdb_0.40_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_7.dat
#
# --- [127/378] Processando: mggdb_0.40_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_8.dat
#
# --- [128/378] Processando: mggdb_0.40_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.40_9.dat
#
# --- [129/378] Processando: mggdb_0.45_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_1.dat
#
# --- [130/378] Processando: mggdb_0.45_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_10.dat
#
# --- [131/378] Processando: mggdb_0.45_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_11.dat
#
# --- [132/378] Processando: mggdb_0.45_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_12.dat
#
# --- [133/378] Processando: mggdb_0.45_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_13.dat
#
# --- [134/378] Processando: mggdb_0.45_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_14.dat
#
# --- [135/378] Processando: mggdb_0.45_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_15.dat
#
# --- [136/378] Processando: mggdb_0.45_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_16.dat
#
# --- [137/378] Processando: mggdb_0.45_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_17.dat
#
# --- [138/378] Processando: mggdb_0.45_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_18.dat
#
# --- [139/378] Processando: mggdb_0.45_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_19.dat
#
# --- [140/378] Processando: mggdb_0.45_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_2.dat
#
# --- [141/378] Processando: mggdb_0.45_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_20.dat
#
# --- [142/378] Processando: mggdb_0.45_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_21.dat
#
# --- [143/378] Processando: mggdb_0.45_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_22.dat
#
# --- [144/378] Processando: mggdb_0.45_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_23.dat
#
# --- [145/378] Processando: mggdb_0.45_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_3.dat
#
# --- [146/378] Processando: mggdb_0.45_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_4.dat
#
# --- [147/378] Processando: mggdb_0.45_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_5.dat
#
# --- [148/378] Processando: mggdb_0.45_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_6.dat
#
# --- [149/378] Processando: mggdb_0.45_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_7.dat
#
# --- [150/378] Processando: mggdb_0.45_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_8.dat
#
# --- [151/378] Processando: mggdb_0.45_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.45_9.dat
#
# --- [152/378] Processando: mggdb_0.50_1.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_1.dat
#
# --- [153/378] Processando: mggdb_0.50_10.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_10.dat
#
# --- [154/378] Processando: mggdb_0.50_11.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_11.dat
#
# --- [155/378] Processando: mggdb_0.50_12.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_12.dat
#
# --- [156/378] Processando: mggdb_0.50_13.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_13.dat
#
# --- [157/378] Processando: mggdb_0.50_14.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_14.dat
#
# --- [158/378] Processando: mggdb_0.50_15.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_15.dat
#
# --- [159/378] Processando: mggdb_0.50_16.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_16.dat
#
# --- [160/378] Processando: mggdb_0.50_17.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_17.dat
#
# --- [161/378] Processando: mggdb_0.50_18.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_18.dat
#
# --- [162/378] Processando: mggdb_0.50_19.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_19.dat
#
# --- [163/378] Processando: mggdb_0.50_2.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_2.dat
#
# --- [164/378] Processando: mggdb_0.50_20.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_20.dat
#
# --- [165/378] Processando: mggdb_0.50_21.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_21.dat
#
# --- [166/378] Processando: mggdb_0.50_22.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_22.dat
#
# --- [167/378] Processando: mggdb_0.50_23.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_23.dat
#
# --- [168/378] Processando: mggdb_0.50_3.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_3.dat
#
# --- [169/378] Processando: mggdb_0.50_4.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_4.dat
#
# --- [170/378] Processando: mggdb_0.50_5.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_5.dat
#
# --- [171/378] Processando: mggdb_0.50_6.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_6.dat
#
# --- [172/378] Processando: mggdb_0.50_7.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_7.dat
#
# --- [173/378] Processando: mggdb_0.50_8.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_8.dat
#
# --- [174/378] Processando: mggdb_0.50_9.dat ---
# ✅ Resultado salvo em solucoes\sol-mggdb_0.50_9.dat
#
# --- [175/378] Processando: mgval_0.25_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_10A.dat
#
# --- [176/378] Processando: mgval_0.25_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_10B.dat
#
# --- [177/378] Processando: mgval_0.25_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_10C.dat
#
# --- [178/378] Processando: mgval_0.25_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_10D.dat
#
# --- [179/378] Processando: mgval_0.25_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_1A.dat
#
# --- [180/378] Processando: mgval_0.25_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_1B.dat
#
# --- [181/378] Processando: mgval_0.25_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_1C.dat
#
# --- [182/378] Processando: mgval_0.25_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_2A.dat
#
# --- [183/378] Processando: mgval_0.25_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_2B.dat
#
# --- [184/378] Processando: mgval_0.25_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_2C.dat
#
# --- [185/378] Processando: mgval_0.25_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_3A.dat
#
# --- [186/378] Processando: mgval_0.25_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_3B.dat
#
# --- [187/378] Processando: mgval_0.25_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_3C.dat
#
# --- [188/378] Processando: mgval_0.25_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_4A.dat
#
# --- [189/378] Processando: mgval_0.25_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_4B.dat
#
# --- [190/378] Processando: mgval_0.25_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_4C.dat
#
# --- [191/378] Processando: mgval_0.25_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_4D.dat
#
# --- [192/378] Processando: mgval_0.25_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_5A.dat
#
# --- [193/378] Processando: mgval_0.25_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_5B.dat
#
# --- [194/378] Processando: mgval_0.25_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_5C.dat
#
# --- [195/378] Processando: mgval_0.25_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_5D.dat
#
# --- [196/378] Processando: mgval_0.25_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_6A.dat
#
# --- [197/378] Processando: mgval_0.25_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_6B.dat
#
# --- [198/378] Processando: mgval_0.25_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_6C.dat
#
# --- [199/378] Processando: mgval_0.25_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_7A.dat
#
# --- [200/378] Processando: mgval_0.25_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_7B.dat
#
# --- [201/378] Processando: mgval_0.25_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_7C.dat
#
# --- [202/378] Processando: mgval_0.25_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_8A.dat
#
# --- [203/378] Processando: mgval_0.25_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_8B.dat
#
# --- [204/378] Processando: mgval_0.25_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_8C.dat
#
# --- [205/378] Processando: mgval_0.25_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_9A.dat
#
# --- [206/378] Processando: mgval_0.25_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_9B.dat
#
# --- [207/378] Processando: mgval_0.25_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_9C.dat
#
# --- [208/378] Processando: mgval_0.25_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.25_9D.dat
#
# --- [209/378] Processando: mgval_0.30_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_10A.dat
#
# --- [210/378] Processando: mgval_0.30_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_10B.dat
#
# --- [211/378] Processando: mgval_0.30_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_10C.dat
#
# --- [212/378] Processando: mgval_0.30_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_10D.dat
#
# --- [213/378] Processando: mgval_0.30_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_1A.dat
#
# --- [214/378] Processando: mgval_0.30_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_1B.dat
#
# --- [215/378] Processando: mgval_0.30_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_1C.dat
#
# --- [216/378] Processando: mgval_0.30_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_2A.dat
#
# --- [217/378] Processando: mgval_0.30_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_2B.dat
#
# --- [218/378] Processando: mgval_0.30_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_2C.dat
#
# --- [219/378] Processando: mgval_0.30_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_3A.dat
#
# --- [220/378] Processando: mgval_0.30_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_3B.dat
#
# --- [221/378] Processando: mgval_0.30_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_3C.dat
#
# --- [222/378] Processando: mgval_0.30_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_4A.dat
#
# --- [223/378] Processando: mgval_0.30_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_4B.dat
#
# --- [224/378] Processando: mgval_0.30_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_4C.dat
#
# --- [225/378] Processando: mgval_0.30_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_4D.dat
#
# --- [226/378] Processando: mgval_0.30_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_5A.dat
#
# --- [227/378] Processando: mgval_0.30_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_5B.dat
#
# --- [228/378] Processando: mgval_0.30_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_5C.dat
#
# --- [229/378] Processando: mgval_0.30_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_5D.dat
#
# --- [230/378] Processando: mgval_0.30_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_6A.dat
#
# --- [231/378] Processando: mgval_0.30_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_6B.dat
#
# --- [232/378] Processando: mgval_0.30_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_6C.dat
#
# --- [233/378] Processando: mgval_0.30_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_7A.dat
#
# --- [234/378] Processando: mgval_0.30_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_7B.dat
#
# --- [235/378] Processando: mgval_0.30_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_7C.dat
#
# --- [236/378] Processando: mgval_0.30_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_8A.dat
#
# --- [237/378] Processando: mgval_0.30_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_8B.dat
#
# --- [238/378] Processando: mgval_0.30_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_8C.dat
#
# --- [239/378] Processando: mgval_0.30_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_9A.dat
#
# --- [240/378] Processando: mgval_0.30_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_9B.dat
#
# --- [241/378] Processando: mgval_0.30_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_9C.dat
#
# --- [242/378] Processando: mgval_0.30_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.30_9D.dat
#
# --- [243/378] Processando: mgval_0.35_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_10A.dat
#
# --- [244/378] Processando: mgval_0.35_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_10B.dat
#
# --- [245/378] Processando: mgval_0.35_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_10C.dat
#
# --- [246/378] Processando: mgval_0.35_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_10D.dat
#
# --- [247/378] Processando: mgval_0.35_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_1A.dat
#
# --- [248/378] Processando: mgval_0.35_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_1B.dat
#
# --- [249/378] Processando: mgval_0.35_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_1C.dat
#
# --- [250/378] Processando: mgval_0.35_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_2A.dat
#
# --- [251/378] Processando: mgval_0.35_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_2B.dat
#
# --- [252/378] Processando: mgval_0.35_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_2C.dat
#
# --- [253/378] Processando: mgval_0.35_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_3A.dat
#
# --- [254/378] Processando: mgval_0.35_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_3B.dat
#
# --- [255/378] Processando: mgval_0.35_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_3C.dat
#
# --- [256/378] Processando: mgval_0.35_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_4A.dat
#
# --- [257/378] Processando: mgval_0.35_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_4B.dat
#
# --- [258/378] Processando: mgval_0.35_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_4C.dat
#
# --- [259/378] Processando: mgval_0.35_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_4D.dat
#
# --- [260/378] Processando: mgval_0.35_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_5A.dat
#
# --- [261/378] Processando: mgval_0.35_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_5B.dat
#
# --- [262/378] Processando: mgval_0.35_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_5C.dat
#
# --- [263/378] Processando: mgval_0.35_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_5D.dat
#
# --- [264/378] Processando: mgval_0.35_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_6A.dat
#
# --- [265/378] Processando: mgval_0.35_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_6B.dat
#
# --- [266/378] Processando: mgval_0.35_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_6C.dat
#
# --- [267/378] Processando: mgval_0.35_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_7A.dat
#
# --- [268/378] Processando: mgval_0.35_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_7B.dat
#
# --- [269/378] Processando: mgval_0.35_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_7C.dat
#
# --- [270/378] Processando: mgval_0.35_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_8A.dat
#
# --- [271/378] Processando: mgval_0.35_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_8B.dat
#
# --- [272/378] Processando: mgval_0.35_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_8C.dat
#
# --- [273/378] Processando: mgval_0.35_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_9A.dat
#
# --- [274/378] Processando: mgval_0.35_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_9B.dat
#
# --- [275/378] Processando: mgval_0.35_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_9C.dat
#
# --- [276/378] Processando: mgval_0.35_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.35_9D.dat
#
# --- [277/378] Processando: mgval_0.40_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_10A.dat
#
# --- [278/378] Processando: mgval_0.40_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_10B.dat
#
# --- [279/378] Processando: mgval_0.40_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_10C.dat
#
# --- [280/378] Processando: mgval_0.40_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_10D.dat
#
# --- [281/378] Processando: mgval_0.40_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_1A.dat
#
# --- [282/378] Processando: mgval_0.40_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_1B.dat
#
# --- [283/378] Processando: mgval_0.40_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_1C.dat
#
# --- [284/378] Processando: mgval_0.40_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_2A.dat
#
# --- [285/378] Processando: mgval_0.40_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_2B.dat
#
# --- [286/378] Processando: mgval_0.40_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_2C.dat
#
# --- [287/378] Processando: mgval_0.40_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_3A.dat
#
# --- [288/378] Processando: mgval_0.40_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_3B.dat
#
# --- [289/378] Processando: mgval_0.40_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_3C.dat
#
# --- [290/378] Processando: mgval_0.40_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_4A.dat
#
# --- [291/378] Processando: mgval_0.40_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_4B.dat
#
# --- [292/378] Processando: mgval_0.40_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_4C.dat
#
# --- [293/378] Processando: mgval_0.40_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_4D.dat
#
# --- [294/378] Processando: mgval_0.40_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_5A.dat
#
# --- [295/378] Processando: mgval_0.40_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_5B.dat
#
# --- [296/378] Processando: mgval_0.40_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_5C.dat
#
# --- [297/378] Processando: mgval_0.40_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_5D.dat
#
# --- [298/378] Processando: mgval_0.40_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_6A.dat
#
# --- [299/378] Processando: mgval_0.40_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_6B.dat
#
# --- [300/378] Processando: mgval_0.40_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_6C.dat
#
# --- [301/378] Processando: mgval_0.40_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_7A.dat
#
# --- [302/378] Processando: mgval_0.40_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_7B.dat
#
# --- [303/378] Processando: mgval_0.40_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_7C.dat
#
# --- [304/378] Processando: mgval_0.40_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_8A.dat
#
# --- [305/378] Processando: mgval_0.40_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_8B.dat
#
# --- [306/378] Processando: mgval_0.40_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_8C.dat
#
# --- [307/378] Processando: mgval_0.40_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_9A.dat
#
# --- [308/378] Processando: mgval_0.40_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_9B.dat
#
# --- [309/378] Processando: mgval_0.40_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_9C.dat
#
# --- [310/378] Processando: mgval_0.40_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.40_9D.dat
#
# --- [311/378] Processando: mgval_0.45_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_10A.dat
#
# --- [312/378] Processando: mgval_0.45_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_10B.dat
#
# --- [313/378] Processando: mgval_0.45_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_10C.dat
#
# --- [314/378] Processando: mgval_0.45_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_10D.dat
#
# --- [315/378] Processando: mgval_0.45_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_1A.dat
#
# --- [316/378] Processando: mgval_0.45_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_1B.dat
#
# --- [317/378] Processando: mgval_0.45_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_1C.dat
#
# --- [318/378] Processando: mgval_0.45_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_2A.dat
#
# --- [319/378] Processando: mgval_0.45_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_2B.dat
#
# --- [320/378] Processando: mgval_0.45_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_2C.dat
#
# --- [321/378] Processando: mgval_0.45_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_3A.dat
#
# --- [322/378] Processando: mgval_0.45_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_3B.dat
#
# --- [323/378] Processando: mgval_0.45_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_3C.dat
#
# --- [324/378] Processando: mgval_0.45_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_4A.dat
#
# --- [325/378] Processando: mgval_0.45_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_4B.dat
#
# --- [326/378] Processando: mgval_0.45_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_4C.dat
#
# --- [327/378] Processando: mgval_0.45_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_4D.dat
#
# --- [328/378] Processando: mgval_0.45_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_5A.dat
#
# --- [329/378] Processando: mgval_0.45_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_5B.dat
#
# --- [330/378] Processando: mgval_0.45_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_5C.dat
#
# --- [331/378] Processando: mgval_0.45_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_5D.dat
#
# --- [332/378] Processando: mgval_0.45_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_6A.dat
#
# --- [333/378] Processando: mgval_0.45_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_6B.dat
#
# --- [334/378] Processando: mgval_0.45_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_6C.dat
#
# --- [335/378] Processando: mgval_0.45_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_7A.dat
#
# --- [336/378] Processando: mgval_0.45_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_7B.dat
#
# --- [337/378] Processando: mgval_0.45_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_7C.dat
#
# --- [338/378] Processando: mgval_0.45_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_8A.dat
#
# --- [339/378] Processando: mgval_0.45_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_8B.dat
#
# --- [340/378] Processando: mgval_0.45_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_8C.dat
#
# --- [341/378] Processando: mgval_0.45_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_9A.dat
#
# --- [342/378] Processando: mgval_0.45_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_9B.dat
#
# --- [343/378] Processando: mgval_0.45_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_9C.dat
#
# --- [344/378] Processando: mgval_0.45_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.45_9D.dat
#
# --- [345/378] Processando: mgval_0.50_10A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_10A.dat
#
# --- [346/378] Processando: mgval_0.50_10B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_10B.dat
#
# --- [347/378] Processando: mgval_0.50_10C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_10C.dat
#
# --- [348/378] Processando: mgval_0.50_10D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_10D.dat
#
# --- [349/378] Processando: mgval_0.50_1A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_1A.dat
#
# --- [350/378] Processando: mgval_0.50_1B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_1B.dat
#
# --- [351/378] Processando: mgval_0.50_1C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_1C.dat
#
# --- [352/378] Processando: mgval_0.50_2A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_2A.dat
#
# --- [353/378] Processando: mgval_0.50_2B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_2B.dat
#
# --- [354/378] Processando: mgval_0.50_2C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_2C.dat
#
# --- [355/378] Processando: mgval_0.50_3A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_3A.dat
#
# --- [356/378] Processando: mgval_0.50_3B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_3B.dat
#
# --- [357/378] Processando: mgval_0.50_3C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_3C.dat
#
# --- [358/378] Processando: mgval_0.50_4A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_4A.dat
#
# --- [359/378] Processando: mgval_0.50_4B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_4B.dat
#
# --- [360/378] Processando: mgval_0.50_4C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_4C.dat
#
# --- [361/378] Processando: mgval_0.50_4D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_4D.dat
#
# --- [362/378] Processando: mgval_0.50_5A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_5A.dat
#
# --- [363/378] Processando: mgval_0.50_5B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_5B.dat
#
# --- [364/378] Processando: mgval_0.50_5C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_5C.dat
#
# --- [365/378] Processando: mgval_0.50_5D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_5D.dat
#
# --- [366/378] Processando: mgval_0.50_6A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_6A.dat
#
# --- [367/378] Processando: mgval_0.50_6B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_6B.dat
#
# --- [368/378] Processando: mgval_0.50_6C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_6C.dat
#
# --- [369/378] Processando: mgval_0.50_7A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_7A.dat
#
# --- [370/378] Processando: mgval_0.50_7B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_7B.dat
#
# --- [371/378] Processando: mgval_0.50_7C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_7C.dat
#
# --- [372/378] Processando: mgval_0.50_8A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_8A.dat
#
# --- [373/378] Processando: mgval_0.50_8B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_8B.dat
#
# --- [374/378] Processando: mgval_0.50_8C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_8C.dat
#
# --- [375/378] Processando: mgval_0.50_9A.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_9A.dat
#
# --- [376/378] Processando: mgval_0.50_9B.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_9B.dat
#
# --- [377/378] Processando: mgval_0.50_9C.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_9C.dat
#
# --- [378/378] Processando: mgval_0.50_9D.dat ---
# ✅ Resultado salvo em solucoes\sol-mgval_0.50_9D.dat
